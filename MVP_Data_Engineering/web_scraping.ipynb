# %% [markdown]
# <a href="https://colab.research.google.com/github/IsabelaAyres/datascience/blob/main/MVP_Data_Engineering/web_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import datetime

# Configuração para não exibir os warnings
import warnings
warnings.filterwarnings("ignore")

# %%
current_time = datetime.datetime.now().strftime('%d/%m/%y %H:%M') #salva o dia e hora atual

# %%
codigo_setor = [42, 82, 32, 152, 203, 2, 92, 52, 62, 112, 102, 12]
dicionario_setor = {42:'acougue', 82:'bebidas', 32:'biscoito', 152:'bombom', 203:'infantil', 2:'cereais', 92:'conservas', 52:'embutidos', 62:'frios', 112:'higienepessoal', 102:'limpeza', 12:'padaria'}

# %%
#Listas para armazenar dados
acougue = []
bebidas = []
biscoito = []
bombom = []
infantil = []
cereais = []
conservas = []
embutidos = []
frios = []
higienepessoal = []
limpeza = []
padaria = []

# %%
#cria df inicial
df = pd.DataFrame()

# %%
for setor in codigo_setor:
    url = "https://www.supermercadosguanabara.com.br/produtos/" + str(setor)
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    Product = soup.find_all('div', {'class': 'name'})
    Price = soup.find_all('div', {'class': 'price'})


    df = pd.DataFrame({"Date": current_time,
                       "Sector": dicionario_setor[setor],
                       "Product": Product[16:],
                       "Price": Price,
                          }).append(df)

# %%
df
# Out:
#               Date   Sector                                     Product  \
# 0   27/09/23 00:00  padaria             [Achocolatado Italakinho 200ml]
# 1   27/09/23 00:00  padaria                       [Café  Melitta  500g]
# 2   27/09/23 00:00  padaria                [Cereal Matinal Nescau 210g]
# 3   27/09/23 00:00  padaria       [Leite em Pó Inst. Italac Sachê 400g]
# 4   27/09/23 00:00  padaria  [Pão de Forma Seven Boys Tradicional 450g]
# ..             ...      ...                                         ...
# 9   27/09/23 00:00  acougue        [Coxinha das Asas de Frango Lar Kg ]
# 10  27/09/23 00:00  acougue                      [Linguiça Perdigão Kg]
# 11  27/09/23 00:00  acougue           [Coxa de Frango Seara Bandeja Kg]
# 12  27/09/23 00:00  acougue            [Coxa de Frango Seara Pacote Kg]
# 13  27/09/23 00:00  acougue            [Filé de Peito de Frango Lar kg]
#
#              Price
# 0    [[[0,99],  ]]
# 1   [[[17,98],  ]]
# 2    [[[8,30],  ]]
# 3   [[[11,99],  ]]
# ...

# %%
#salvar arquivo
df.to_csv('CAMINHO/WebScraping-Guanabara.csv', index=False)
